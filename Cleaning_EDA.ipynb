# %%
import pandas as pd

df = pd.read_csv("raw_salesData.csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
cols_to_drop = ["Row ID", "Product ID", "Postal Code", "Customer ID"]
df.drop(columns=cols_to_drop, inplace=True)

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode    Customer Name  \
# 0  CA-2013-152156  09-11-2013  12-11-2013    Second Class      Claire Gute
# 1  CA-2013-152156  09-11-2013  12-11-2013    Second Class      Claire Gute
# 2  CA-2013-138688  13-06-2013  17-06-2013    Second Class  Darrin Van Huff
# 3  US-2012-108966  11-10-2012  18-10-2012  Standard Class   Sean O'Donnell
# 4  US-2012-108966  11-10-2012  18-10-2012  Standard Class   Sean O'Donnell
#
#      Segment        Country             City       State Region  \
# 0   Consumer  United States        Henderson    Kentucky  South
# 1   Consumer  United States        Henderson    Kentucky  South
# 2  Corporate  United States      Los Angeles  California   West
# 3   Consumer  United States  Fort Lauderdale     Florida  South
# 4   Consumer  United States  Fort Lauderdale     Florida  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer Name  9994 non-null   object
#  5   Segment        9994 non-null   object
#  6   Country        9994 non-null   object
#  7   City           9994 non-null   object
#  8   State          9994 non-null   object
#  9   Region         9994 non-null   object
#  10  Category       9994 non-null   object
#  11  Sub-Category   9994 non-null   object
#  12  Product Name   9994 non-null   object
#  13  Sales          9994 non-null   float64
#  14  Quantity       9994 non-null   int64
#  15  Discount       9994 non-null   float64
#  16  Profit         9994 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Region           0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
df[df.duplicated()]
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode   Customer Name  \
# 3406  US-2011-150119  23-04-2011  27-04-2011  Standard Class  Laurel Beltran
#
#           Segment        Country      City State Region   Category  \
# 3406  Home Office  United States  Columbus  Ohio   East  Furniture
#
#      Sub-Category                                       Product Name    Sales  \
# 3406       Chairs  Global Leather Highback Executive Chair with P...  281.372
#
#       Quantity  Discount   Profit
# 3406         2       0.3 -12.0588

# %%
df.drop_duplicates(inplace=True)

# %%
# coverting date cols from string to date_time objects
df['Order Date'] = pd.to_datetime(df['Order Date'], format="%d-%m-%Y")
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format="%d-%m-%Y")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9993 non-null   object
#  1   Order Date     9993 non-null   datetime64[ns]
#  2   Ship Date      9993 non-null   datetime64[ns]
#  3   Ship Mode      9993 non-null   object
#  4   Customer Name  9993 non-null   object
#  5   Segment        9993 non-null   object
#  6   Country        9993 non-null   object
#  7   City           9993 non-null   object
#  8   State          9993 non-null   object
#  9   Region         9993 non-null   object
#  10  Category       9993 non-null   object
#  11  Sub-Category   9993 non-null   object
#  12  Product Name   9993 non-null   object
#  13  Sales          9993 non-null   float64
#  14  Quantity       9993 non-null   int64
#  15  Discount       9993 non-null   float64
#  16  Profit         9993 non-null   float64
# ...

# %%
df.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9993                           9993
# mean   2013-04-30 21:06:30.153107200  2013-05-04 20:07:16.625637888
# min              2011-01-04 00:00:00            2011-01-08 00:00:00
# 25%              2012-05-23 00:00:00            2012-05-27 00:00:00
# 50%              2013-06-27 00:00:00            2013-06-30 00:00:00
# 75%              2014-05-15 00:00:00            2014-05-19 00:00:00
# max              2014-12-31 00:00:00            2015-01-06 00:00:00
# std                              NaN                            NaN
#
#               Sales     Quantity     Discount       Profit
# count   9993.000000  9993.000000  9993.000000  9993.000000
# mean     229.852846     3.789753     0.156188    28.660971
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.731000
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Create the profile
profile = ProfileReport(df, 
                        title="Sales Dataset Profiling Report",
                        explorative=True)

# %%
profile.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.select_dtypes(include=['number']).lt(0).sum()
# Out:
# Sales          0
# Quantity       0
# Discount       0
# Profit      1870
# dtype: int64

# %%
df.to_csv("sales.csv",index=False)
